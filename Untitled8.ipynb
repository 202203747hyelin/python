# %% [markdown]
# <a href="https://colab.research.google.com/github/202203747hyelin/python/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# [1점] matplotlib을 이용하여 구간 [0,2]에서 함수 f(x) = x^2 + sin(3x+7) 함수의 그래프를 그리세요. 

import numpy as np
import matplotlib.pyplot as plt

X=np.linspace(0,4*np.pi,200)
Y=np.sin(X)

def f(x):
	return x^2 + sin(3*x+7)
 
a = 0
b = 2
 
plt.plot([0,2])
plt.show()

# %%
### 2D gradient descent 구현 


### 출처: https://mazdah.tistory.com/833 [꿈을 위한 단상:티스토리]에 나온 gradient descent코드를 gradient부분만 살짝 추가한 코드입니다.

import numpy as np
import matplotlib.pyplot as plt
#import math
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return a + (1/2)* b**2 +2* np.sin(3*a)

def grad_f(a,b): # gradient
  h=1e-5
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]


def gradient_descent(theta0, iters, alpha):
	history = [theta0] # to store all thetas
	theta = theta0     # initial values for thetas
	# main loop by iterations:
	for i in range(iters):
		gradient = grad_f(theta[0],theta[1]) #함수 f(x,y)의 gradient
		# update parameters:
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-1, -2], iters =25, alpha = 0.08)

# f(x,y) = x^2 + y^2 함수의 그래프 그리기
fig = plt.figure(figsize=(20, 15))
ax = fig.gca(projection='3d')
#plt.hold(True)
a = np.arange(-2, 2, 0.25)
b = np.arange(-2, 2, 0.25)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
		 linewidth=0, antialiased=False, cmap='rainbow')


a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)
## c= 0 ## 최소값을 찾기 위한 부분
ax.scatter(a, b, c, color="r"); 

print(c)


plt.xlabel('Feature A')
plt.ylabel('Feature B')

##plt.axis('equal')

plt.show()
# Out:
# [ 0.71775998 -0.85294852 -1.11769535 -1.33855972 -1.52497359 -1.68265917
#  -1.81610769 -1.92905557 -2.02465414 -2.10556869 -2.17405474 -2.23202133
#  -2.28108425 -2.32261111 -2.35775944 -2.38750899 -2.41268901 -2.43400137
#  -2.45204016 -2.46730819 -2.48023105 -2.49116896 -2.50042681 -2.50826265
#  -2.5148949  -2.52050844]

# %%
import pandas as pd

targetUrl_caf= "https://www.kaggle.com/datasets/heitornunes/caffeine-content-of-drinks.csv"

caffeine = pd.read_csv(targetUrl_caf)

caffeine.head(n=10)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-1-f246d2a73350> in <module>
#       3 targetUrl_caf= "https://www.kaggle.com/datasets/heitornunes/caffeine-content-of-drinks.csv"
#       4
# ----> 5 caffeine = pd.read_csv(targetUrl_caf)
#       6
#       7 caffeine.head(n=10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
Volume (ml) = caffeine['Volume (ml)']

print(Volume (ml).max())
print(Volume (ml).mean())


print(Volume (ml)[Volume (ml) > Volume (ml).mean()])  ## 불린 추출

print(Volume (ml) > Volume (ml).mean())
# Out:
#   File "<ipython-input-7-0c7f9fe115e2>", line 1
#     Volume (ml) = caffeine['Volume (ml)']
#                                          ^
# SyntaxError: can't assign to function call

# %%
print(caffeine[ scientists['Volume (ml)'] > caffeine['Volume (ml)'].mean() ]) ## 불린 추출
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-7c089c138490> in <module>
# ----> 1 print(caffeine[ scientists['Volume (ml)'] > caffeine['Volume (ml)'].mean() ]) ## 불린 추출
#
# NameError: name 'caffeine' is not defined

# %%
print(caffeine['Volume (ml)'])

print(caffeine['Calories'].dtype) #object는 문자열을 의미

print(caffeine['Caffeine (mg)'].dtype)

# %%
## caffeine['Calories']와 caffeine['Caffeine (mg)']을 datetime

Calories_datetime = pd.to_datetime(caffeine['Calories'],format='%Y-%m-%d')

print(Calories_datetime)

changed_one=Calories_datetime.dt.strftime('%m/%d/%Y')

print(changed_one)

###one_more=pd.to_datetime(changed_one.astype(str), format='%m/%d/%Y') ## 고민 중

##print(one_more)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-a32dd02657b3> in <module>
#       1 ## caffeine['Calories']와 caffeine['Caffeine (mg)']을 datetime
#       2
# ----> 3 Calories_datetime = pd.to_datetime(caffeine['Calories'],format='%Y-%m-%d')
#       4
#       5 print(Calories_datetime)
#
# NameError: name 'caffeine' is not defined

# %%
Caffeine (mg)_datatime = pd.to_datetime(caffeine['Caffeine (mg)'],format='%Y-%m-%d')

print(died_datatime)

caffeine['Calories_dt'], caffeine['Caffeine (mg)_dt'] = (Calories_datetime, Caffeine (mg)_datatime)


print(caffeine.head())

# %%
caffeine['life_days'] =  caffeine['Caffeine (mg)_dt'] - caffeine['Calories_dt']

print(caffeine)

# %%
## 마구 섞기

print(Caffeine['Volume (ml)'])

import random

random.seed(2)

random.shuffle(Caffeine (mg)['Volume (ml)'])

print(Caffeine (mg)['Volume (ml)'])

print(Caffeine (mg).iloc[:,0:4])

# %%
## 피클로 만들어 저장하고 꺼내오기.

import os

print(os.getcwd())

## os.chdir('/content/')

names = Caffeine['Name']

names.to_pickle('../content/Caffeine_names.pickle')

return_names = pd.read_pickle('../content/Caffeine_names.pickle')

print(return_names)

# %%
### seaborn 라이브러리 = matplotlib에 구축된 데이터 시각화 라이브러리로 통계 그래프를 그린다.

import seaborn as sns

targetUrl_iris="https://www.kaggle.com/datasets/heitornunes/caffeine-content-of-drinks.csv"

irisData = pd.read_csv(targetUrl_iris)

print(irisData.shape)

print(irisData.head())

irisData.tail()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-64-0abdf062a3d0> in <module>
#       5 targetUrl_iris="https://www.kaggle.com/datasets/heitornunes/caffeine-content-of-drinks.csv"
#       6
# ----> 7 irisData = pd.read_csv(targetUrl_iris)
#       8
#       9 print(irisData.shape)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
sns.set_theme()
sns.set(rc={"figure.dpi":300}) #이미지 품질 설정
sns.set(rc={"figure.figsize":(6,3)}) ## 크기설정


## Scatter plot 산점도

sns.scatterplot(x="drink_Volume (ml)", y ="drink_Calories", data=irisData, hue ='Caffeine (mg)')

# %%
## 히스토그램 histogram

sns.histplot( y= "drink_Calories", data = irisData)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3c9b1ed73c4c> in <module>
#       1 ## 히스토그램 histogram
#       2
# ----> 3 sns.histplot( y= "drink_Calories", data = irisData)
#
# NameError: name 'sns' is not defined

# %%
sns.histplot( x= "drink_Volume (ml)", data = irisData)

# %%
sns.histplot( x= "drink_Volume (ml)", data = irisData, kde = "True")

# %%
sns.histplot( x= "drink_Volume (ml)", data = irisData, hue = "Species")

# %%
## Barplot : 숫자 변수의 경향 추청치를 보여준다.

sns.barplot(x="drink_Volume (ml)", y="drink_Calories", data =irisData)

# %%
## Box plot

sns.boxplot(x="drink_Volume (ml)", y="drink_Calories", data=irisData)
